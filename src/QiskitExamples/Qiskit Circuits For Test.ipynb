# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister, Aer, execute
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_histogram, plot_bloch_multivector, plot_state_city
from numpy import pi
import csv

# Function to save state vectors to a CSV file
def save_statevector_to_csv(filename, statevectors):
    with open(filename, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["Circuit", "State Vector"])
        
        for i, statevector in enumerate(statevectors):
            # Convert the state vector to a comma-separated string and replace 'j' with 'i'
            statevector_str = ','.join([str(val).replace('j', 'i') for val in statevector])
            
            # Write each state vector as a single line in the CSV
            writer.writerow([f"Circuit {i+1}", statevector_str])

simulator = Aer.get_backend('statevector_simulator')
statevectors = []

# Circuit Base.
circuit = QuantumCircuit(4)

circuit.x(0)
circuit.h(1)
circuit.x(1)
circuit.h(3)
circuit.ccx(0, 1, 2)
circuit.cx(0, 1)
circuit.cx(3, 2)

display(circuit.draw('mpl'))

result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print(statevector)
#statevectors.append(statevector)


# Circuit 1: Single h gate.
circuit = QuantumCircuit(1)
circuit.h(0)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 1:", statevector)
statevectors.append(statevector)


# Circuit 2: Single x gate.
circuit = QuantumCircuit(1)
circuit.x(0)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 2:", statevector)
statevectors.append(statevector)

# Circuit 3: Single z gate.
circuit = QuantumCircuit(1)
circuit.z(0)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 3:", statevector)
statevectors.append(statevector)

# Circuit 4: Two same gates, h and h.
circuit = QuantumCircuit(1)
circuit.h(0)
circuit.h(0)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 4:", statevector)
statevectors.append(statevector)

# Circuit 5: Two different gates, h and x.
circuit = QuantumCircuit(1)
circuit.h(0)
circuit.x(0)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 5:", statevector)
statevectors.append(statevector)

# Circuit 6: Two qubits, h on first qubit and x on second.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.x(1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 6:", statevector)
statevectors.append(statevector)

# Circuit 7: Two qubits, cx (CNOT) with h on the first.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cx(0, 1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 7:", statevector)
statevectors.append(statevector)

# Circuit 8: Three qubits, h, x, and z on different qubits.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.x(1)
circuit.z(2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 8:", statevector)
statevectors.append(statevector)

# Circuit 9: Three qubits, hadamard on all qubits.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.h(1)
circuit.h(2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 9:", statevector)
statevectors.append(statevector)

# Circuit 10: Four qubits, random gate arrangement.
circuit = QuantumCircuit(4)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.cx(0, 1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 10:", statevector)
statevectors.append(statevector)

# Circuit 11: Four qubits, two CX gates.
circuit = QuantumCircuit(4)
circuit.h(0)
circuit.h(1)
circuit.cx(0, 1)
circuit.cx(1, 2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 11:", statevector)
statevectors.append(statevector)

# Circuit 12: Two qubits, h and x gates on both qubits.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.h(1)
circuit.x(0)
circuit.x(1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 12:", statevector)
statevectors.append(statevector)

# Circuit 13: Three qubits, cx between all qubits.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.cx(0, 1)
circuit.cx(1, 2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 13:", statevector)
statevectors.append(statevector)

# Circuit 14: Four qubits, random combination of h, x, z, and cx.
circuit = QuantumCircuit(4)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.cx(0, 1)
circuit.cx(1, 2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 14:", statevector)
statevectors.append(statevector)

# Circuit 15: Five qubits, h on all qubits, followed by cx between adjacent pairs.
circuit = QuantumCircuit(5)
circuit.h(0)
circuit.h(1)
circuit.h(2)
circuit.h(3)
circuit.h(4)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.cx(2, 3)
circuit.cx(3, 4)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 15:", statevector)
statevectors.append(statevector)

# Circuit 16: Three qubits, alternating h and x gates with cx on first and last.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.x(1)
circuit.h(2)
circuit.cx(1, 2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 16:", statevector)
statevectors.append(statevector)

# Circuit 17: Five qubits, mix of h, x, and z gates.
circuit = QuantumCircuit(5)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.h(3)
circuit.x(4)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 17:", statevector)
statevectors.append(statevector)

# Circuit 18: Two qubits.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cx(0, 1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 18:", statevector)
statevectors.append(statevector)

# Circuit 19: Four qubits, random gates on each qubit with multiple cx.
circuit = QuantumCircuit(4)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.h(3)
circuit.cx(0, 1)
circuit.cx(2, 3)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 19:", statevector)
statevectors.append(statevector)

# Circuit 20: Three qubits, all h gates.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.h(1)
circuit.h(2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 20:", statevector)
statevectors.append(statevector)

# Circuit 21: Two qubits, mix of h, x, and z gates with cx.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.x(1)
#circuit.z(0)
circuit.x(0)
circuit.cx(0, 1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 21:", statevector)
statevectors.append(statevector)

# Circuit 22: Three qubits, complex sequence of h, x, cx, and z gates.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.h(0)
circuit.x(2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 22:", statevector)
statevectors.append(statevector)

# Circuit 23: Five qubits, alternating h, x, and z gates.
circuit = QuantumCircuit(5)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.h(3)
circuit.x(4)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 23:", statevector)
statevectors.append(statevector)

# Circuit 24: Four qubits, random gates followed by cx.
circuit = QuantumCircuit(4)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.h(3)
circuit.cx(0, 1)
circuit.cx(2, 3)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 24:", statevector)
statevectors.append(statevector)

# Circuit 25: Six qubits, combination of h, x, z, cz, and swap gates.
circuit = QuantumCircuit(6)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.cz(3, 4)
circuit.h(5)
circuit.swap(0, 1)
circuit.swap(2, 3)
circuit.cz(4, 5)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 25:", statevector)
statevectors.append(statevector)

# Circuit 26: Seven qubits, deep chain of cx and ccx gates.
circuit = QuantumCircuit(7)
circuit.h(0)
circuit.h(1)
circuit.h(2)
circuit.ccx(0, 1, 2)
circuit.cx(3, 4)
circuit.cx(4, 5)
circuit.cx(5, 6)
circuit.ccx(2, 3, 4)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 26:", statevector)
statevectors.append(statevector)

# Circuit 27: Eight qubits, full entanglement with multiple cx and cz gates.
circuit = QuantumCircuit(8)
circuit.h(0)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.cx(2, 3)
circuit.cz(3, 4)
circuit.cz(4, 5)
circuit.cz(5, 6)
circuit.cz(6, 7)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 27:", statevector)
statevectors.append(statevector)

# Circuit 28: Ten qubits, random combination of gates creating a highly entangled state.
circuit = QuantumCircuit(10)
circuit.h(0)
circuit.x(1)
circuit.cx(0, 2)
circuit.z(3)
circuit.ccx(4, 5, 6)
circuit.h(7)
circuit.swap(8, 9)
circuit.cx(7, 8)
circuit.cx(6, 7)
circuit.cx(5, 4)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 28:", statevector)
statevectors.append(statevector)

# Circuit 29: Twelve qubits, multiple levels of controlled operations and entanglements.
circuit = QuantumCircuit(12)
circuit.h(0)
circuit.x(1)
circuit.ccx(2, 3, 4)
circuit.h(5)
circuit.cx(0, 6)
circuit.cx(6, 7)
circuit.cx(7, 8)
circuit.swap(9, 10)
circuit.cz(11, 0)
circuit.cz(1, 2)
circuit.cx(3, 4)
circuit.cx(5, 6)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 29:", statevector)
statevectors.append(statevector)

# Circuit 30: Fourteen qubits, deeply nested entanglements using cx, ccx, cz, and swap.
circuit = QuantumCircuit(14)
circuit.h(0)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.cx(2, 3)
circuit.ccx(4, 5, 6)
circuit.h(7)
circuit.cx(8, 9)
circuit.cz(10, 11)
circuit.cz(12, 13)
circuit.cx(7, 8)
circuit.cx(6, 7)
circuit.ccx(5, 6, 7)
circuit.swap(10, 12)
circuit.swap(11, 13)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 30:", statevector)
statevectors.append(statevector)

# Circuit 31: Fifteen qubits, high complexity with multiple controlled gates and entanglements.
circuit = QuantumCircuit(15)
circuit.h(0)
circuit.h(1)
circuit.cx(0, 2)
circuit.cx(1, 3)
circuit.ccx(2, 3, 4)
circuit.h(5)
circuit.cx(4, 6)
circuit.cx(6, 7)
circuit.ccx(7, 8, 9)
circuit.cz(10, 11)
circuit.swap(12, 13)
circuit.cz(13, 14)
circuit.cx(9, 10)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 31:", statevector)
statevectors.append(statevector)

# Circuit 32: Seventeen qubits, mix of cx, ccx, swap, and cz.
circuit = QuantumCircuit(17)
circuit.h(0)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.ccx(2, 3, 4)
circuit.cx(4, 5)
circuit.cx(5, 6)
circuit.cx(6, 7)
circuit.cz(7, 8)
circuit.cz(8, 9)
circuit.ccx(9, 10, 11)
circuit.cx(11, 12)
circuit.swap(12, 13)
circuit.cx(13, 14)
circuit.cz(14, 15)
circuit.swap(15, 16)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 32:", statevector)
statevectors.append(statevector)

# Circuit 33: Eighteen qubits, extensive multi-controlled operations.
circuit = QuantumCircuit(18)
circuit.h(0)
circuit.x(1)
circuit.h(2)
circuit.ccx(3, 4, 5)
circuit.ccx(5, 6, 7)
circuit.cx(7, 8)
circuit.cx(8, 9)
circuit.ccx(9, 10, 11)
circuit.cx(11, 12)
circuit.cx(12, 13)
circuit.cx(13, 14)
circuit.cz(15, 16)
circuit.cx(16, 17)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 33:", statevector)
statevectors.append(statevector)

# Circuit 34: Two qubits, a dense mix of h, x, z, cz, and cx gates.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.x(1)
circuit.z(0)
circuit.h(1)
circuit.cx(0, 1)
circuit.h(0)
circuit.cx(1, 0)
circuit.z(1)
circuit.x(0)
circuit.cx(0, 1)
circuit.h(1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 34:", statevector)
statevectors.append(statevector)

# Circuit 35: Two qubits, dense.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.z(1)
circuit.cx(0, 1)
circuit.h(1)
circuit.z(0)
circuit.cx(1, 0)
circuit.x(0)
circuit.h(1)
circuit.h(0)
circuit.cx(0, 1)
circuit.z(1)
circuit.h(0)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 35:", statevector)
statevectors.append(statevector)

# Circuit 36: Three qubits, cx and cz with some h, x, z.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.cx(0, 1)
circuit.h(1)
circuit.cz(1, 2)
circuit.h(0)
circuit.cx(2, 1)
circuit.cx(0, 2)
circuit.z(1)
circuit.x(2)
circuit.cx(0, 1)
circuit.h(2)
circuit.cz(1, 0)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 36:", statevector)
statevectors.append(statevector)

# Circuit 37: Three qubits, dense mixture of h, x, z, cx, and cz gates.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.x(1)
circuit.z(2)
circuit.h(1)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.cz(2, 0)
circuit.h(0)
circuit.cx(1, 0)
circuit.z(2)
circuit.h(1)
circuit.x(0)
circuit.h(2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 37:", statevector)
statevectors.append(statevector)

# Circuit 38: Two qubits, intense use of gates cx, h, z, x in a small system.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.cx(0, 1)
circuit.x(1)
circuit.z(0)
circuit.h(1)
circuit.h(0)
circuit.cx(0, 1)
circuit.z(1)
circuit.x(0)
circuit.cx(1, 0)
circuit.h(1)
circuit.h(0)
circuit.z(1)
circuit.cx(0, 1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 38:", statevector)
statevectors.append(statevector)

# Circuit 39: Three qubits, dense set of gates.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.h(1)
circuit.h(2)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.cx(2, 0)
circuit.z(0)
circuit.h(1)
circuit.x(2)
circuit.cx(0, 1)
circuit.cx(2, 1)
circuit.z(2)
circuit.x(0)
circuit.h(0)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 39:", statevector)
statevectors.append(statevector)

# Circuit 40: Two qubits, highly entangled and dense gate setup.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.x(1)
circuit.z(0)
circuit.cx(0, 1)
circuit.cx(1, 0)
circuit.h(0)
circuit.h(1)
circuit.x(0)
circuit.z(1)
circuit.cx(0, 1)
circuit.h(0)
circuit.h(1)
circuit.cx(0, 1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 40:", statevector)
statevectors.append(statevector)

# Circuit 41: Three qubits, heavy use of gates h, cx, cz in minimal space.
circuit = QuantumCircuit(3)
circuit.h(0)
circuit.h(1)
circuit.h(2)
circuit.cx(0, 1)
circuit.cx(1, 2)
circuit.cx(2, 0)
circuit.h(0)
circuit.h(1)
circuit.h(2)
circuit.cz(1, 0)
circuit.cz(2, 1)
circuit.cz(0, 2)
circuit.h(0)
circuit.h(1)
circuit.h(2)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 41:", statevector)
statevectors.append(statevector)

# Circuit 42: Two qubits, gates packed tightly together for maximum interaction.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.x(1)
circuit.cx(0, 1)
circuit.cx(1, 0)
circuit.h(1)
circuit.h(0)
circuit.z(1)
circuit.x(0)
circuit.cx(1, 0)
circuit.cx(0, 1)
circuit.h(0)
circuit.h(1)
circuit.z(0)
circuit.cx(1, 0)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 42:", statevector)
statevectors.append(statevector)

# Circuit 43: Two qubits, using all available gates densely packed.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.z(1)
circuit.cx(0, 1)
circuit.x(0)
circuit.h(1)
circuit.cx(1, 0)
circuit.z(1)
circuit.cx(0, 1)
circuit.h(0)
circuit.cx(1, 0)
circuit.x(1)
circuit.h(0)
circuit.z(1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 43:", statevector)
statevectors.append(statevector)

# Circuit 44: Two qubits, densely packed mixture of cx, h, z, and x gates.
circuit = QuantumCircuit(2)
circuit.h(0)
circuit.x(1)
circuit.cx(0, 1)
circuit.h(1)
circuit.z(0)
circuit.h(0)
circuit.h(1)
circuit.cx(0, 1)
circuit.z(1)
circuit.h(0)
circuit.cx(1, 0)
circuit.cx(0, 1)

display(circuit.draw('mpl'))
result = execute(circuit, simulator).result()
statevector = result.get_statevector(circuit)
print("Circuit 44:", statevector)
statevectors.append(statevector)

save_statevector_to_csv("statevectors.csv", statevectors)

print("done")
# Out:
# Statevector([0. +0.j, 0. +0.j, 0. +0.j, 0.5+0.j, 0. +0.j, 0.5+0.j, 0. +0.j,
#              0. +0.j, 0. +0.j, 0.5+0.j, 0. +0.j, 0. +0.j, 0. +0.j, 0. +0.j,
#              0. +0.j, 0.5+0.j],
#             dims=(2, 2, 2, 2))
# Circuit 1: Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))
# Circuit 2: Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))
# Circuit 3: Statevector([ 1.+0.j, -0.+0.j],
#             dims=(2,))
# Circuit 4: Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))
# Circuit 5: Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))
# Circuit 6: Statevector([0.        +0.j, 0.        +0.j, 0.70710678+0.j,
#              0.70710678+0.j],
#             dims=(2, 2))
# Circuit 7: Statevector([0.70710678+0.j, 0.        +0.j, 0.        +0.j,
#              0.70710678+0.j],
#             dims=(2, 2))
# Circuit 8: Statevector([ 0.        +0.j,  0.        +0.j,  0.70710678+0.j,
# ...
